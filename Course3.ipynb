# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openai.vocareum.com/v1",
    api_key="YOUR_API_KEY"
)

# %%
# Out:
# Creating synthetic startup dataset...
# Dataset shape: (50, 11)
# Columns: ['name', 'type', 'category', 'country', 'status', 'market', 'funding_usd', 'founded_year', 'team_size', 'description', 'text']
#
# Sample data:
#         name         type       category  \
# 0  Startup_1  API Service     E-commerce
# 1  Startup_2         SaaS  Cybersecurity
# 2  Startup_3   Mobile App     Healthtech
# 3  Startup_4  Marketplace          AI/ML
# 4  Startup_5          B2C    Real Estate
#
#                                                 text
# 0  Startup_1 | Type: API Service | Category: E-co...
# 1  Startup_2 | Type: SaaS | Category: Cybersecuri...
# 2  Startup_3 | Type: Mobile App | Category: Healt...
# 3  Startup_4 | Type: Marketplace | Category: AI/M...
# 4  Startup_5 | Type: B2C | Category: Real Estate ...
# ✅ Dataset ready with 50 rows!

# %%
# !pip install kagglehub
# !pip install tiktoken
# !pip install -U scikit-learn
# !pip install numpy
# !pip install pandas
# !pip install openai
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.11/dist-packages (0.3.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->kagglehub) (2025.8.3)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.10.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.8.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 69.0 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# Successfully installed scikit-learn-1.7.1
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.99.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)

# %%
import kagglehub
import pandas as pd
import numpy as np
import json
import os

path = kagglehub.dataset_download("manishkc06/startup-success-prediction")
print("Path to dataset files:", path)

# List files in the downloaded directory to confirm the filename
print("Files in directory:", os.listdir(path))

# Construct the full path to the CSV file
csv_file_path = f"{path}/startup data.csv"
df_raw = pd.read_csv(csv_file_path)
print(df_raw.shape)
df_raw.head()
df = df_raw.copy()

df.columns = [c.strip().lower().replace(" ", "_") for c in df.columns]

df = df.dropna(how="all").drop_duplicates()

if len(df) < 20:
    raise ValueError("Dataset does not contain at least 20 rows after cleaning.")

candidate_cols = [
    "name", "category_list", "country_code", "state_code", "region", "city",
    "status", "funding_total_usd", "funding_rounds", "founded_at", "first_funding_at",
    "last_funding_at", "milestones", "relationships", "age_first_funding_year",
    "age_last_funding_year", "is_top500", "markets", "description"
]
existing = [c for c in candidate_cols if c in df.columns]

def row_to_text(row):
    parts = []
    for c in existing:
        val = row.get(c, None)
        if pd.notna(val):
            parts.append(f"{c}: {val}")
    return " | ".join(map(str, parts)) if parts else ""

df["text"] = df.apply(row_to_text, axis=1)

non_empty_text = df["text"].replace("", np.nan).dropna()
if len(non_empty_text) < 20:
    df["text"] = df.apply(lambda r: json.dumps(r.to_dict(), default=str), axis=1)

assert "text" in df.columns
assert len(df) >= 20

df[["text"]].head(3)
# Out:
# Path to dataset files: /kaggle/input/startup-success-prediction
# Files in directory: ['startup data.csv']
# (923, 49)
#                                                 text
# 0  name: Bandsintown | state_code: CA | city: San...
# 1  name: TriCipher | state_code: CA | city: Los G...
# 2  name: Plixi | state_code: CA | city: San Diego...

# %%
import os
import json
import pandas as pd
import numpy as np
from pathlib import Path
from openai import OpenAI

client = OpenAI(
    base_url="https://openai.vocareum.com/v1",
    api_key="YOUR_API_KEY"
)

print("Generating embeddings")
corpus = df["text"].astype(str).tolist()

def generate_embeddings(texts, model="text-embedding-3-small"):
    embeddings = []
    for i, text in enumerate(texts):
        if i % 50 == 0:
            print(f"Processing text {i+1}/{len(texts)}")
        try:
            response = client.embeddings.create(
                model=model,
                input=text
            )
            embeddings.append(response.data[0].embedding)
        except Exception as e:
            print(f"Error generating embedding for text {i}: {e}")
            embeddings.append([0.0] * 1536)
    return np.array(embeddings)

corpus_embeddings = generate_embeddings(corpus)
print(f"Generated embeddings shape: {corpus_embeddings.shape}")
print("Embeddings generation completed!")
# Out:
# Generating embeddings
# Processing text 1/923
# Processing text 51/923
# Processing text 101/923
# Processing text 151/923
# Processing text 201/923
# Processing text 251/923
# Processing text 301/923
# Processing text 351/923
# Processing text 401/923
# Processing text 451/923
# Processing text 501/923
# Processing text 551/923
# Processing text 601/923
# Processing text 651/923
# Processing text 701/923
# Processing text 751/923
# Processing text 801/923
# Processing text 851/923
# Processing text 901/923
# Generated embeddings shape: (923, 1536)
# Embeddings generation completed!

# %%
def cosine_similarity_manual(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm1 = np.linalg.norm(vec1)
    norm2 = np.linalg.norm(vec2)
    return dot_product / (norm1 * norm2)

def vector_similarity_search(query_embedding, corpus_embeddings, corpus_texts, top_k=5):
    similarities = []
    for i, corpus_emb in enumerate(corpus_embeddings):
        sim = cosine_similarity_manual(query_embedding, corpus_emb)
        similarities.append((sim, i))

    similarities.sort(reverse=True, key=lambda x: x[0])

    results = []
    for sim_score, idx in similarities[:top_k]:
        results.append({
            'text': corpus_texts[idx],
            'similarity_score': sim_score
        })

    return results

def embedding_based_retriever(query, corpus_texts, corpus_embeddings, top_k=5):
    query_embedding = generate_embeddings([query])[0]
    similar_texts = vector_similarity_search(query_embedding, corpus_embeddings, corpus_texts, top_k)
    return [item['text'] for item in similar_texts]

# %%
BASIC_SYSTEM_PROMPT = (
    "You are a helpful assistant. Answer concisely and accurately."
)

CUSTOM_SYSTEM_PROMPT = (
    "You are a Startup Idea Validator and Business Plan Assistant. "
    "Use the provided startup dataset context to ground your answers. "
    "Prioritize evidence on funding, market, team, and traction. "
    "Identify assumptions, ask for missing info if critical, and give actionable next steps."
)

def build_custom_user_prompt(question, retrieved_context):
    ctx_block = "\n\n".join([f"- {c}" for c in retrieved_context])
    return (
        "Context from startup dataset:\n"
        f"{ctx_block}\n\n"
        "User Question:\n"
        f"{question}\n\n"
        "Instructions:\n"
        "- Cite relevant signals from the context (funding, market, team, geography).\n"
        "- Provide at least 3 concrete next steps for validation.\n"
        "- If context is thin, state limitations and what extra data is needed."
    )

# %%
MODEL_NAME = "gpt-4o-mini"

def ask_basic(question):
    messages = [
        {"role": "system", "content": BASIC_SYSTEM_PROMPT},
        {"role": "user", "content": question},
    ]
    resp = client.chat.completions.create(model=MODEL_NAME, messages=messages, temperature=0.3)
    return resp.choices[0].message.content

def ask_custom(question):
    retrieved = embedding_based_retriever(question, corpus, corpus_embeddings, top_k=5)
    user_prompt = build_custom_user_prompt(question, retrieved)
    messages = [
        {"role": "system", "content": CUSTOM_SYSTEM_PROMPT},
        {"role": "user", "content": user_prompt},
    ]
    resp = client.chat.completions.create(model=MODEL_NAME, messages=messages, temperature=0.3)
    return resp.choices[0].message.content

questions = [
    "Evaluate the success likelihood for a B2C wellness app in United States raising a seed round. What signals from similar startups matter most? Give Citations from the dataset.",
    "What market and funding risks should a SaaS startup in the US consider before Series A, and how can they mitigate them?"
]

results = []
for q in questions:
    basic = ask_basic(q)
    custom = ask_custom(q)
    results.append({"question": q, "basic_answer": basic, "custom_answer": custom})

for i, r in enumerate(results, 1):
    print(f"\n=== Question {i} ===")
    print(r["question"])
    print("\n--- Basic Answer ---")
    print(r["basic_answer"])
    print("\n--- Custom Answer ---")
    print(r["custom_answer"])
# Out:
# Processing text 1/1
# Processing text 1/1
#
# === Question 1 ===
# Evaluate the success likelihood for a B2C wellness app in United States raising a seed round. What signals from similar startups matter most? Give Citations from the dataset.
#
# --- Basic Answer ---
# Evaluating the success likelihood for a B2C wellness app in the United States raising a seed round involves analyzing several key factors and signals from similar startups. Here are the most relevant considerations:
#
# 1. **Market Demand**: The wellness industry has seen significant growth, with consumers increasingly prioritizing health and wellness. According to the Global Wellness Institute, the wellness economy was valued at $4.5 trillion in 2018 and continues to expand. A strong market demand for wellness solutions is a positive signal.
#
# 2. **User Engagement Metrics**: Startups that demonstrate high user engagement (e.g., daily active users, session length) tend to have better retention rates. Metrics from successful wellness apps like Calm and Headspace indicate that user engagement is critical for long-term success.
#
# 3. **Monetization Strategy**: Successful wellness apps often have clear and scalable monetization strategies, such as subscription models, in-app purchases, or partnerships. For instance, Headspace's subscription model has proven effective in generating revenue.
#
# 4. **Competitive Landscape**: Analyzing the competition is crucial. Startups that differentiate themselves through unique features, user experience, or niche targeting (e.g., mental health, fitness, nutrition) can stand out. For example, apps like MyFitnessPal and Noom have carved out specific niches within the wellness space.
#
# 5. **Founding Team Experience**: The background and expertise of the founding team play a significant role in attracting investors. Teams with experience in tech, health, or wellness industries are often viewed more favorably.
#
# 6. **Funding Trends**: Recent funding trends in the wellness sector indicate a growing interest from investors. According to Crunchbase, wellness startups raised over $1 billion in venture capital in 2021 alone, signaling investor confidence in this space.
#
# 7. **User Feedback and Reviews**: Positive user feedback and high ratings on app stores can indicate potential for growth. Apps with strong community engagement and positive testimonials tend to attract more users.
#
# 8. **Partnerships and Collaborations**: Startups that establish partnerships with health organizations, influencers, or other tech companies can enhance credibility and reach.
#
# In summary, a B2C wellness app in the U.S. has a favorable success likelihood if it can demonstrate strong market demand, user engagement, a solid monetization strategy, a competitive edge, an experienced founding team, and positive user feedback. Monitoring funding trends and establishing strategic partnerships can also significantly enhance its chances of success.
#
# --- Custom Answer ---
# To evaluate the success likelihood for a B2C wellness app in the United States raising a seed round, we can draw insights from the provided dataset of similar startups. Here are the key signals to consider:
#
# ### Relevant Signals from Similar Startups
#
# 1. **Funding**:
#    - The funding amounts for acquired startups in the dataset vary significantly. For instance, RetailMeNot, Inc. raised $299,500,000, while Appstores.com raised only $1,155,000. This indicates that while some wellness apps can scale significantly and attract large investments, others have been successful with smaller funding rounds. The average funding for the wellness-related startups in the dataset (like GoodGuide and ShopWell) is around $14 million, which suggests that a seed round should aim for a substantial amount to gain traction.
#
# 2. **Market and Geography**:
#    - The majority of successful startups in the dataset are located in California, particularly in tech hubs like San Francisco and Palo Alto. This geographic concentration suggests that being situated in a major tech ecosystem can provide better access to investors, talent, and partnerships. A B2C wellness app should consider establishing itself in a similar environment to leverage these advantages.
#
# 3. **Team and Relationships**:
#    - The number of relationships can indicate the strength of a startup's network, which is crucial for growth. For example, RetailMeNot has 37 relationships, while ShopWell has 4. A strong network can facilitate partnerships, customer acquisition, and funding opportunities. A B2C wellness app should focus on building a robust network early on.
#
# 4. **Milestones and Traction**:
#    - The number of milestones achieved can reflect the startup's progress and potential for future success. For instance, GoodGuide and ShopWell both achieved multiple milestones before being acquired. A B2C wellness app should aim to set and achieve clear milestones to demonstrate traction to potential investors.
#
# ### Next Steps for Validation
#
# 1. **Market Research**: Conduct thorough market research to identify the current trends in the wellness app sector, including consumer preferences and competitive landscape. This will help in understanding the potential market size and customer acquisition strategies.
#
# 2. **Build a Prototype**: Develop a minimum viable product (MVP) to test the concept with a target audience. Gathering user feedback will be crucial to refine the app and demonstrate traction to potential investors.
#
# 3. **Network Development**: Actively seek to build relationships with industry experts, potential partners, and investors. Attend industry events, join relevant online communities, and leverage platforms like LinkedIn to connect with key stakeholders in the wellness and tech sectors.
#
# ### Limitations and Additional Data Needed
#
# - **User Engagement Metrics**: Information on user engagement and retention rates for existing wellness apps would provide insights into what drives success in this market.
# - **Competitive Analysis**: Data on direct competitors, including their funding rounds, user base, and growth metrics, would help in positioning the new app effectively.
# - **Team Background**: Information on the founding team’s experience and expertise in the wellness or tech industry would be valuable to assess the likelihood of success.
#
# By focusing on these areas and leveraging the insights from the dataset, a B2C wellness app can better position itself for a successful seed round and future growth.
#
# === Question 2 ===
# What market and funding risks should a SaaS startup in the US consider before Series A, and how can they mitigate them?
#
# --- Basic Answer ---
# A SaaS startup in the US should consider the following market and funding risks before Series A:
#
# ### Market Risks:
#
# 1. **Market Demand**: Uncertainty about whether there is sufficient demand for the product.
#    - **Mitigation**: Conduct thorough market research, validate the product-market fit through customer interviews, and gather feedback from early adopters.
#
# 2. **Competition**: The presence of established competitors or new entrants can impact growth.
#    - **Mitigation**: Analyze competitors, identify unique value propositions, and develop a strong go-to-market strategy.
#
# 3. **Customer Acquisition**: Difficulty in acquiring customers at a sustainable cost.
#    - **Mitigation**: Test various marketing channels, optimize the sales funnel, and focus on customer retention strategies.
#
# 4. **Scalability**: Concerns about whether the business model can scale effectively.
#    - **Mitigation**: Build a scalable infrastructure and continuously assess operational efficiencies.
#
# 5. **Changing Market Trends**: Rapid changes in technology or customer preferences.
#    - **Mitigation**: Stay informed about industry trends and be adaptable to pivot if necessary.
#
# ### Funding Risks:
#
# 1. **Investor Interest**: Difficulty in attracting investors for Series A funding.
#    - **Mitigation**: Build a solid business case with traction metrics, a clear growth plan, and a compelling narrative.
#
# 2. **Valuation Expectations**: Misalignment between founder and investor expectations on valuation.
#    - **Mitigation**: Research comparable company valuations and be prepared to justify your valuation based on metrics.
#
# 3. **Dilution**: Concerns about excessive dilution of ownership.
#    - **Mitigation**: Plan funding rounds carefully and consider alternative funding options like convertible notes or SAFE agreements.
#
# 4. **Runway and Burn Rate**: Insufficient runway to reach key milestones before the next funding round.
#    - **Mitigation**: Create a detailed financial plan, monitor cash flow closely, and adjust spending as necessary.
#
# 5. **Economic Conditions**: Broader economic downturns affecting investor sentiment.
#    - **Mitigation**: Maintain a diversified funding strategy and build relationships with multiple potential investors.
#
# By proactively addressing these risks, a SaaS startup can enhance its chances of a successful Series A funding round.
#
# --- Custom Answer ---
# When considering market and funding risks for a SaaS startup in the US before Series A, several key factors from the provided dataset can provide insights into potential challenges and strategies for mitigation.
#
# ### Market Risks:
# 1. **Market Demand and Competition**: The success of SaaS startups often hinges on identifying a strong market demand and understanding competitive dynamics. For instance, both Sana Security and Sometrics were acquired, indicating they found a product-market fit that attracted buyers. However, startups like Sampa and Avega Systems faced challenges, as evidenced by their closure.
#
#    **Mitigation**: Conduct thorough market research to validate the demand for your product. Analyze competitors and identify unique value propositions that differentiate your offering.
#
# 2. **Customer Acquisition and Retention**: The number of relationships (as seen with Sometrics having 10) can indicate the startup's ability to build a customer base. A low number of relationships may signal challenges in customer acquisition.
#
#    **Mitigation**: Develop a robust go-to-market strategy that includes customer feedback loops, pilot programs, and partnerships to enhance customer acquisition and retention.
#
# ### Funding Risks:
# 1. **Funding Environment**: The dataset shows varying funding amounts and rounds. For example, Sana Security successfully raised $12 million in one round, while ZoomSafer raised $3.35 million over four rounds. This disparity highlights the importance of understanding funding trends in the SaaS space.
#
#    **Mitigation**: Prepare a compelling pitch that clearly outlines your business model, market opportunity, and traction. Build relationships with potential investors early to gauge interest and feedback.
#
# 2. **Funding Timing**: The age at which startups secured their first and last funding can indicate the urgency and timing of funding needs. For instance, ZoomSafer had a relatively short time between funding rounds, which might suggest a need for rapid growth.
#
#    **Mitigation**: Establish a clear financial roadmap that outlines when and how much funding will be needed, and align it with key milestones to demonstrate progress to investors.
#
# ### Next Steps for Validation:
# 1. **Conduct Market Research**: Gather data on market size, growth rates, and competitive analysis. Utilize surveys, interviews, and industry reports to validate the demand for your SaaS solution.
#
# 2. **Develop a Minimum Viable Product (MVP)**: Create an MVP to test your product in the market. Gather user feedback to iterate on features and improve the offering based on real-world usage.
#
# 3. **Build Investor Relationships**: Start networking with potential investors, attending industry events, and pitching your concept to gather insights and gauge interest. This will also help refine your pitch based on feedback.
#
# ### Limitations and Missing Data:
# - The dataset lacks specific information about the team behind each startup, which is critical for understanding execution capability.
# - There is no data on customer feedback or satisfaction, which would help assess market fit.
# - Information on the specific SaaS niche or verticals these companies operated in would provide better context for market risks.
#
# By addressing these areas, a SaaS startup can better navigate the risks associated with market demand and funding, ultimately positioning itself for a successful Series A round.

# %%
def chat_loop():
    print("Startup Idea Validator Chatbot (type 'exit' to quit)")
    while True:
        q = input("\nYour question: ").strip()
        if q.lower() in {"exit", "quit"}:
            print("Goodbye!")
            break
        try:
            print("\n[Basic]")
            print(ask_basic(q))
            print("\n[Custom - uses dataset context]")
            print(ask_custom(q))
        except Exception as e:
            print("Error:", e)

demo_question = (
    "Based on similar startups, what early traction should a fintech app show "
    "before approaching seed investors in United States? Give answer along with citations from the dataset."
)

print("Custom query with dataset context:\n")
print(ask_custom(demo_question))
# Out:
# Custom query with dataset context:
#
# Processing text 1/1
# To effectively approach seed investors in the United States, a fintech app should demonstrate early traction through several key indicators, as evidenced by the dataset of similar startups:
#
# ### Relevant Signals from the Dataset
#
# 1. **Funding**:
#    - Startups like KickApps and AppTrigger received significant funding ($39 million and $21.5 million respectively) within a few years of their founding. This indicates that early traction can often be linked to securing substantial initial investments.
#    - For instance, KickApps had three funding rounds, suggesting a strong investor interest and confidence in its growth potential.
#
# 2. **Milestones**:
#    - The number of milestones achieved can be a strong indicator of traction. For example, KickApps achieved five milestones, while Appature and Appstores.com achieved two milestones each. These milestones could include product launches, user acquisition targets, or partnerships, which are critical for demonstrating growth to potential investors.
#
# 3. **Relationships**:
#    - The number of relationships a startup has can indicate its network and potential market reach. For example, KickApps had 22 relationships, while StartupDigest had 11. Building a strong network can help in user acquisition and partnerships, which are crucial for fintech apps.
#
# 4. **Geography**:
#    - The dataset shows that successful startups are located in tech hubs like New York, San Francisco, and Seattle. Being in a well-connected ecosystem can provide better access to investors and resources.
#
# ### Concrete Next Steps for Validation
#
# 1. **Establish Milestones**:
#    - Set clear, measurable milestones that align with user acquisition, product development, and market entry. Aim for at least two to three significant milestones within the first 12-18 months to demonstrate progress.
#
# 2. **Build Relationships**:
#    - Actively network with industry professionals, potential partners, and mentors in the fintech space. Aim to establish at least 5-10 strategic relationships that can help validate your business model and provide introductions to investors.
#
# 3. **Prepare a Funding Strategy**:
#    - Develop a clear funding strategy that outlines how much capital is needed, how it will be used, and the expected outcomes. Consider starting with a smaller seed round to build traction and then leverage that success for larger funding rounds, similar to the approach taken by KickApps.
#
# ### Limitations and Additional Data Needed
#
# While the dataset provides valuable insights, it lacks specific details about the fintech app's current status, market size, competitive landscape, and user feedback. Additional data that would be beneficial includes:
#
# - **Market Research**: Information on the target market size and growth potential for the fintech app.
# - **User Metrics**: Current user engagement metrics or beta testing results to gauge interest and validate the product.
# - **Competitive Analysis**: Insights into competitors in the fintech space and how the app differentiates itself.
#
# Gathering this information will help refine the approach to investors and strengthen the case for funding.
